# %% [markdown]
# # Phase 2 — Image Deepfake Training
#
# This notebook trains EfficientNet-B4 on FaceForensics++ for binary real/fake classification.
#
# **Target:** ≥90% AUC-ROC
#
# **Runtime:** Google Colab GPU

# %%
# TODO: Phase 2 — Image Training
# 1. Load FaceForensics++ images
# 2. Face-crop with MTCNN, resize to 224x224
# 3. Load EfficientNet-B4, replace head
# 4. Train with augmentations
# 5. Evaluate: AUC-ROC
# 6. Save weights

print('Image Training Notebook — TODO')
