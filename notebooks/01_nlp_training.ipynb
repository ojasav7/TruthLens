# %% [markdown]
# # Phase 1 — NLP Fake News Training
#
# This notebook fine-tunes BERT on LIAR + FakeNewsNet datasets for binary fake/real classification.
#
# **Target:** ≥85% accuracy
#
# **Runtime:** Google Colab GPU (T4 or better)

# %%
# TODO: Phase 1 — NLP Training
# 1. Load LIAR + FakeNewsNet datasets
# 2. Merge and clean into (text, label) CSV
# 3. Tokenize with bert-base-uncased
# 4. Fine-tune BertForSequenceClassification (2 labels)
# 5. Evaluate: accuracy, F1, confusion matrix
# 6. Save weights to models/nlp/weights/

print('NLP Training Notebook — TODO')
